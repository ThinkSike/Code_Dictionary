# %%
# If-Else: Determine the eligibility to vote, contest election, or none based on age.
def check_eligibility(age):
    if age >= 18:
        if age >= 21:
            return "Eligible to contest elections"
        else:
            return "Eligible to vote"
    else:
        return "Not eligible to vote or contest elections"

# %%
# Loop: Generate and display a matrix pattern.
def generate_matrix(n):
    matrix = []
    for i in range(n):
        row = []
        for j in range(n):
            if (i + j) % 2 == 0:
                row.append(1)
            else:
                row.append(0)
        matrix.append(row)
    return matrix

# %%
# Function: Write a function that removes all duplicates from a list.
def remove_duplicates(lst):
    return list(set(lst))

# %%
# If-Else: Check if a given year is a leap year using only mathematical operations.
def is_leap_year(year):
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
        return True
    else:
        return False

# %%
# Loop: Print a symmetrical triangle of numbers up to a given row.
def print_triangle(rows):
    for i in range(1, rows + 1):
        print(' ' * (rows - i) + ' '.join(str(j) for j in range(1, i + 1)))

# %%
# Function: Define a function to sort a list without using built-in functions.
def bubble_sort(lst):
    n = len(lst)
    for i in range(n):
        for j in range(0, n-i-1):
            if lst[j] > lst[j+1]:
                lst[j], lst[j+1] = lst[j+1], lst[j]
    return lst

# %%
# If-Else: Classify a number as positive, negative or zero and even or odd.
def classify_number(num):
    if num > 0:
        if num % 2 == 0:
            return "Positive Even"
        else:
            return "Positive Odd"
    elif num < 0:
        if num % 2 == 0:
            return "Negative Even"
        else:
            return "Negative Odd"
    else:
        return "Zero"

# %%
# Loop: Print alternating 1s and 0s triangle pattern.
def print_alternating_triangle(rows):
    for i in range(1, rows + 1):
        for j in range(i):
            print(1 if (i + j) % 2 == 0 else 0, end=' ')
        print()

# %%
# Function: Create a function that checks if a list is sorted in non-decreasing order.
def is_sorted(lst):
    return all(lst[i] <= lst[i + 1] for i in range(len(lst) - 1))

# %%
# If-Else: Check whether a year is a leap year and divisible by 400.
def is_leap_year_and_divisible_by_400(year):
    if year % 4 == 0:
        if year % 100 == 0:
            if year % 400 == 0:
                return True
            else:
                return False
        else:
            return True
    else:
        return False

# %%
# Loop: Print an hourglass pattern using stars.
def print_hourglass(rows):
    for i in range(rows, 0, -1):
        print(' ' * (rows - i) + '* ' * i)
    for i in range(2, rows + 1):
        print(' ' * (rows - i) + '* ' * i)
print_hourglass(5)
# Out:
# * * * * *
#  * * * *
#   * * *
#    * *
#     *
#    * *
#   * * *
#  * * * *
# * * * * *

# %%
# Function: Define a function to compute GCD using subtraction method.
def gcd_subtraction(a, b):
    while b:
        a, b = b, a - b if a > b else a
    return a

# %%
# If-Else: Accept an integer and determine if it’s a buzz number.
def is_buzz_number(num):
    if num % 7 == 0 or '7' in str(num):
        return True
    else:
        return False

# %%
# Loop: Generate hollow half-pyramid pattern.
def hollow_half_pyramid(rows):
    for i in range(1, rows + 1):
        for j in range(1, i + 1):
            if j == 1 or j == i or i == rows:
                print('*', end=' ')
            else:
                print(' ', end=' ')
        print()

# %%
# Function: Write a function that finds the nth term in the Lucas sequence.
def lucas(n):
    if n == 0:
        return 2
    elif n == 1:
        return 1
    else:
        a, b = 2, 1
        for _ in range(2, n + 1):
            a, b = b, a + b
        return b

# %%
# If-Else: Validate user credentials using nested if-else.
def validate_credentials(username, password):
    if username == "admin":
        if password == "password123":
            return "Access granted"
        else:
            return "Invalid password"
    else:
        return "Invalid username"

# %%
# Loop: Print a spiral matrix using nested loops.
def spiral_matrix(n):
    matrix = [[0] * n for _ in range(n)]
    left, right, top, bottom = 0, n - 1, 0, n - 1
    num = 1

    while left <= right and top <= bottom:
        for i in range(left, right + 1):
            matrix[top][i] = num
            num += 1
        top += 1

        for i in range(top, bottom + 1):
            matrix[i][right] = num
            num += 1
        right -= 1

        if top <= bottom:
            for i in range(right, left - 1, -1):
                matrix[bottom][i] = num
                num += 1
            bottom -= 1

        if left <= right:
            for i in range(bottom, top - 1, -1):
                matrix[i][left] = num
                num += 1
            left += 1

    return matrix

# %%
# Function: Create a function to convert binary to decimal.
def binary_to_decimal(binary_str):
    decimal = 0
    for i, digit in enumerate(reversed(binary_str)):
        decimal += int(digit) * (2 ** i)
    return decimal

# %%
# If-Else: Categorize temperature into cold, moderate or hot.
def categorize_temperature(temp):
    if temp < 15:
        return "Cold"
    elif 15 <= temp <= 30:
        return "Moderate"
    else:
        return "Hot"

# %%
# Loop: Print diamond-shaped number pattern.
def print_diamond_pattern(n):
    for i in range(1, n + 1):
        print(' ' * (n - i) + ' '.join(str(j) for j in range(1, i + 1)))
    for i in range(n - 1, 0, -1):
        print(' ' * (n - i) + ' '.join(str(j) for j in range(1, i + 1)))

# %%
# Function: Write a recursive function to generate Fibonacci numbers.
def fibonacci(n):
    if n <= 0:
        return []
    elif n == 1:
        return [0]
    elif n == 2:
        return [0, 1]
    else:
        fib_seq = fibonacci(n - 1)
        fib_seq.append(fib_seq[-1] + fib_seq[-2])
        return fib_seq

# %%
# If-Else: Evaluate and categorize BMI.
def evaluate_bmi(weight, height):
    bmi = weight / (height ** 2)
    if bmi < 18.5:
        return "Underweight"
    elif 18.5 <= bmi < 24.9:
        return "Normal weight"
    elif 25 <= bmi < 29.9:
        return "Overweight"
    else:
        return "Obesity"

# %%
# Loop: Print the sum of squares of the first n natural numbers.
def sum_of_squares(n):
    total = 0
    for i in range(1, n + 1):
        total += i ** 2
    return total

# %%
# Function: Create a function to rotate elements in a list.
def rotate_list(lst, k):
    n = len(lst)
    k = k % n  # Handle cases where k is greater than n
    return lst[-k:] + lst[:-k]
rotate_list([1, 2, 3, 4, 5], 3)  # Example usage
# Out:
# [3, 4, 5, 1, 2]

# %%
# If-Else: Determine if a number is a Trimorphic number.
def is_trimorphic(num):
    cube = num ** 3
    return str(cube).endswith(str(num))
is_trimorphic(5) # trimorphic number example because 5^3 = 125 ends with 5
# Out:
# True

# %%
# Function: Define a function to count even and odd numbers in a list.
def count_even_odd(lst):
    even_count = sum(1 for x in lst if x % 2 == 0)
    odd_count = len(lst) - even_count
    return even_count, odd_count

# %%
# If-Else: Determine which of three numbers is the median.  
def median_of_three(a, b, c):
    if (a >= b and a <= c) or (a <= b and a >= c):
        return a
    elif (b >= a and b <= c) or (b <= a and b >= c):
        return b
    else:
        return c

# %%
# Loop: Create pattern of alternating characters.
def alternating_pattern(n):
    for i in range(n):
        for j in range(n):
            if (i + j) % 2 == 0:
                print('A', end=' ')
            else:
                print('B', end=' ')
        print()
alternating_pattern(5)
# Out:
# A B A B A
# B A B A B
# A B A B A
# B A B A B
# A B A B A

# %%
# Function: Write a function to check if a list contains only unique elements.
def has_unique_elements(lst):
    return len(lst) == len(set(lst))

# %%
# If-Else: Accept coordinates and detect if a point lies on x/y axis or origin.
def check_coordinates(x, y):
    if x == 0 and y == 0:
        return "Origin"
    elif x == 0:
        return "Y-axis"
    elif y == 0:
        return "X-axis"
    else:
        return "Point is not on any axis"

# %%
# Loop: Print a zigzag number pattern.
def zigzag_pattern(n):
    for i in range(n):
        for j in range(n):
            if (i + j) % 2 == 0:
                print(i + 1, end=' ')
            else:
                print(j + 1, end=' ')
        print()
zigzag_pattern(3)
# Out:
# 1 2 1
# 1 2 3
# 3 2 3

# %%
# Function: Write a function to merge two sorted lists.
def merge_sorted_lists(list1, list2):
    merged_list = []
    i, j = 0, 0
    while i < len(list1) and j < len(list2):
        if list1[i] < list2[j]:
            merged_list.append(list1[i])
            i += 1
        else:
            merged_list.append(list2[j])
            j += 1
    merged_list.extend(list1[i:])
    merged_list.extend(list2[j:])
    return merged_list

# %%
# If-Else: Validate time in HH:MM format.
def validate_time(time_str):
    try:
        hours, minutes = map(int, time_str.split(':'))
        if 0 <= hours < 24 and 0 <= minutes < 60:
            return "Valid time"
        else:
            return "Invalid time"
    except ValueError:
        return "Invalid format"

# %%
#  Loop: Display multiplication tables from 1 to 10.
def display_multiplication_tables():
    for i in range(1, 11):
        print(f"Multiplication Table of {i}:")
        for j in range(1, 11):
            print(f"{i} x {j} = {i * j}")
        print()  # Print a newline for better readability

# %%
# Function: Create a function to convert infix expression to postfix.
def infix_to_postfix(expression):
    precedence = {'+': 1, '-': 1, '*': 2, '/': 2, '^': 3}
    output = []
    stack = []

    for char in expression:
        if char.isalnum():  # If the character is an operand
            output.append(char)
        elif char == '(':
            stack.append(char)
        elif char == ')':
            while stack and stack[-1] != '(':
                output.append(stack.pop())
            stack.pop()  # Pop the '(' from the stack
        else:  # Operator
            while (stack and stack[-1] != '(' and
                   precedence[char] <= precedence[stack[-1]]):
                output.append(stack.pop())
            stack.append(char)

    while stack:
        output.append(stack.pop())

    return ''.join(output)
