# %%
from PIL import Image
path = r"C:\Users\DESPU\017_DIP\071_python\image.png"
# Open an image file
img = Image.open(path)

# %%
# Rotate
img.rotate(45, expand=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=284x284>

# %%
#Scale
# Define the new size (width, height)
new_size = (500, 300)
# Resize the image
img.resize(new_size)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x300>

# %%
# Flip
img.transpose(Image.ROTATE_180)
# Out:
# <PIL.Image.Image image mode=RGBA size=184x216>

# %%
# Resize the image
img.resize((300, 300))
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300>

# %%
# # def resize_image(image_path, output_path, size):
   
# #     image = Image.open('C:\\Users\\Lenovo300s\\Desktop\\horse.jpg')
# #     resized_image = image.resize(size)
# #     resized_image.save('C:\\Users\\Lenovo300s\\Desktop\\resized1.jpg')
# #     print(f"Image resized and saved to {output_path}")

# def crop_image(image_path, output_path, crop_box):
 
#     image = Image.open('C:\\Users\\Lenovo300s\\Desktop\\horse.jpg')
#     cropped_image = image.crop(crop_box)
#     cropped_image.save('C:\\Users\\Lenovo300s\\Desktop\\cropped1.jpg')
#     print(f"Image cropped and saved to {output_path}")

# # def flip_image(image_path, output_path, direction):
   
# #     image = Image.open('C:\\Users\\Lenovo300s\\Desktop\\horse.jpg')
# #     if direction == 'horizontal':
# #         flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
# #     elif direction == 'vertical':
# #         flipped_image = image.transpose(Image.FLIP_TOP_BOTTOM)
# #     else:
# #         raise ValueError("Direction should be either 'horizontal' or 'vertical'.")
# #     flipped_image.save('C:\\Users\\Lenovo300s\\Desktop\\flipped1.jpg')
# #     print(f"Image flipped and saved to {'C:\\Users\\Lenovo300s\\Desktop\\flipped1.jpg'}")

# # def rotate_image(image_path, output_path, angle):
 
# #     image = Image.open('C:\\Users\\Lenovo300s\\Desktop\\horse.jpg')
# #     rotated_image = image.rotate(angle)
# #     rotated_image.save('C:\\Users\\Lenovo300s\\Desktop\\rotated1.jpg')
# #     print(f"Image rotated and saved to {'C:\\Users\\Lenovo300s\\Desktop\\rotated.jpg'}")

# if __name__ == "__main__":
#     'C:\\Users\\Lenovo300s\\Desktop\\horse.jpg' == "horse.jpg"  # Replace with your input image path
# #     output_image_path_resize = "resized1_image.jpg"
# #     output_image_path_crop = "cropped1_image.jpg"
# #     output_image_path_flip = "flipped1_image.jpg"
# #     output_image_path_rotate = "rotated1_image.jpg"
   
 
#     # resize_image('C:\\Users\\Lenovo300s\\Desktop\\horse.jpg', 'C:\\Users\\Lenovo300s\\Desktop\\resized1.jpg', (500, 300))
   
   
#     crop_image('C:\\Users\\Lenovo300s\\Desktop\\horse.jpg', 'C:\\Users\\Lenovo300s\\Desktop\\cropped1.jpg', (100, 100, 500, 500))
   

#     # flip_image('C:\\Users\\Lenovo300s\\Desktop\\horse.jpg', 'C:\\Users\\Lenovo300s\\Desktop\\flipped1.jpg', 'vertical')
   
   
#     # rotate_image('C:\\Users\\Lenovo300s\\Desktop\\horse.jpg', 'C:\\Users\\Lenovo300s\\Desktop\\rotated1.jpg', 45)
