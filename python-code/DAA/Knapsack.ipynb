# %%
# import pandas as pd
# # products = {}
# # # weights = {}
# # # profit_bias = {}
# # x = int(input("Enter no of objects:"))
# # for i in range (0, x):
# #     product = []

# %%
# def compute_profit(n, profit_bias, weights, capacity):
#     while(weights <= capacity):
#         x = 1
#     else:
#         x = x * 0.5
#     capacity = capacity - weights * x
#     profit = profit_bias * x
#     print(pd.DataFrame({i:[weights, profit_bias, x, capacity, profit]}))
#     for i in range(0, n):
#         total_profit = sum(profit[i])
#     return total_profit

# %%
# n = int(input("Enter no of objects:"))
# capacity = float(input("Enter capacity of knapsack:"))

# for i in range (0, n):

#     profit_bias = float(input(f"Profit from p{i}: "))
#     weights = float(input(f"Weight of p{i}: ")) 
#     profit_ratio = profit_bias % weights
#     print(pd.DataFrame({i:[weights, profit_bias, profit_ratio]}))
# #     object_table = pd.DataFrame(
# #         {
# #             i:[weights, profit_bias, profit_ratio]
# #         }
# #     )

# # object_table
# Out:
#      0
# 0  5.0
# 1  5.0
# 2  0.0
#      1
# 0  4.0
# 1  3.0
# 2  3.0
#       2
# 0   4.0
# 1  23.0
# 2   3.0

# %%
# n = 3
# capacity = 20

# for i in range (0, n):

#     profit_bias = float(input(f"Profit from p{i}: "))
#     weights = float(input(f"Weight of p{i}: ")) 
#     profit_ratio = profit_bias % weights
#     print(pd.DataFrame({i:[weights, profit_bias, profit_ratio]}))
#     object_table = pd.DataFrame(
#         {
#             i:[weights, profit_bias, profit_ratio]
#         }
#     )

# # object_table

# %%
# # Function to solve the Fractional Knapsack problem
# def fractional_knapsack(capacity, profits, weights):
#     n = len(profits)
    
#     # Create list of items with (profit, weight, ratio)
#     items = []
#     for i in range(n):
#         ratio = profits[i] / weights[i]
#         items.append((ratio, profits[i], weights[i]))

#     # Sort items by profit-to-weight ratio in descending order
#     items.sort(reverse=True)

#     total_value = 0.0  # Total profit
#     for ratio, profit, weight in items:
#         if capacity >= weight:
#             # Take the whole item
#             capacity -= weight
#             total_value += profit
#         else:
#             # Take fractional part of the item
#             total_value += ratio * capacity
#             break

#     return total_value


# # ------------------ Main Program ------------------

# n = int(input("Enter number of products: "))
# profits = []
# weights = []

# for i in range(n):
#     profit = float(input(f"Enter profit of product {i + 1}: "))
#     weight = float(input(f"Enter weight of product {i + 1}: "))
#     profits.append(profit)
#     weights.append(weight)

# capacity = float(input("Enter the capacity of the knapsack: "))

# max_profit = fractional_knapsack(capacity, profits, weights)

# print(f"Maximum profit that can be obtained = {max_profit:.2f}")

# %%
def knapsack():

# %%
n = int(input("Enter no of products: "))
profit_bias = []
weights = [] # profit_ratio = []

for i in range(n):
    profit = float(input(f"Enter profit of product {i + 1}:"))
    weight = float(input(f"Enter weight of product {i + 1}:"))

    profit_bias.append(profit)
    weights.append(weight)
    # profit_ratio.append(profit / weight)

capacity = float(input("Enter capacity of the knapsack: "))

max_profit = knapsack(capacity, profit_bias, weights)
print(f"Maximum profit obtained: {max_profit:.2f}")
# print(profit_ratio) # sorted_profit_ratio = [] # sorted_profit_ratio = sorted(profit_ratio) # print(sorted_profit_ratio)
# Out:
# [1.3888888888888888, 1.6, 1.5]
# [1.3888888888888888, 1.5, 1.6]
